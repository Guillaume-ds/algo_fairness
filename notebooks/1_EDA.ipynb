# %% [markdown]
# # EDA and Dataset Description

# %%
import pandas as pd
import utils

# %% [markdown]
# ## Data Exploration

# %%
compas_scores_raw, cox_violent_parsed_filt, cox_violent_parsed = utils.read_data_files(frugal=False)

# %% [markdown]
# There are 3 datasets :
# - compas_scores_raw
# - cox_violent_parsed_filt
# - cox_violent_parsed

# %%
compas_scores_raw.iloc[:5,:20]
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ScaleSet_ID            ScaleSet  \
# 0          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 1          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 2          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 3          Male        Caucasian    09/16/84           22  Risk and Prescreen
# 4          Male        Caucasian    09/16/84           22  Risk and Prescreen
#
# ...

# %%
cox_violent_parsed_filt.iloc[:5,20:]
# Out:
#    is_recid r_charge_degree  r_days_from_arrest r_offense_date  \
# 0         0             NaN                 NaN            NaN
# 1         0             NaN                 NaN            NaN
# 2        -1             NaN                 NaN            NaN
# 3         1            (F3)                 NaN     05/07/2013
# 4         1            (M1)                 0.0     16/06/2013
#
#                  r_charge_desc   r_jail_in  violent_recid  is_violent_recid  \
# 0                          NaN         NaN            NaN                 0
# 1                          NaN         NaN            NaN                 0
# 2                          NaN         NaN            NaN                 0
# 3  Felony Battery (Dom Strang)         NaN            NaN                 1
# 4  Driving Under The Influence  16/06/2013            NaN                 0
#
#   vr_charge_degree vr_offense_date               vr_charge_desc  \
# ...

# %%
set(cox_violent_parsed_filt.columns) - set(cox_violent_parsed.columns)
# Out:
# set()

# %%
cox_violent_parsed_filt[(cox_violent_parsed_filt.is_recid == 0) & (cox_violent_parsed_filt.is_violent_recid == 1) ]
# Out:
# Empty DataFrame
# Columns: [id, name, first, last, sex, dob, age, age_cat, race, juv_fel_count, decile_score, juv_misd_count, juv_other_count, priors_count, days_b_screening_arrest, c_jail_in, c_jail_out, c_days_from_compas, c_charge_degree, c_charge_desc, is_recid, r_charge_degree, r_days_from_arrest, r_offense_date, r_charge_desc, r_jail_in, violent_recid, is_violent_recid, vr_charge_degree, vr_offense_date, vr_charge_desc, type_of_assessment, decile_score.1, score_text, screening_date, v_type_of_assessment, v_decile_score, v_score_text, priors_count.1, event]
# Index: []
#
# [0 rows x 40 columns]
